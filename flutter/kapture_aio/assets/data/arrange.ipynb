# %%
import pandas as pd

# 讀取 CSV 檔案
df = pd.read_csv('DCFeverRecommend.csv', header=None)

# %%
df
# Out:
#                      0                                                  1  \
# 0                 香港公園              雀鳥、蓮花、荷花等題材 \n (Photo by charlie.bb )
# 1                 九龍公園                     雀鳥攝影 \n (Photo by dickson_5b )
# 2                   米埔              雀鳥攝影(需申請許可証) \n (Photo by mujihk9394)
# 3                  尖鼻咀                          候鳥攝影 \n (Photo by Singx2)
# 4                  南生圍  候鳥攝影 \n (Photo by A-Lex) \n  \n 景點相片、遊記︰ \n ht...
# ..                 ...                                                ...
# 197              石梨貝水塘  http://www.dcfever.com/travel/attraction.php?i...
# 198               張保仔洞  http://www.dcfever.com/travel/attraction.php?i...
# 199              梧桐寨瀑布  Photo by eddiekky \n 景點介紹、相片、遊記︰ \n http://www...
# 200        大嶼山昂平 / 寶蓮寺  Photo by kinsonleekakin \n 景點介紹、相片、遊記︰ \n http...
# 201  香港天際100觀景台 sky100  天際 100 香港觀景台位於全港最高的環球貿易廣場 100 樓，是全港唯一能 360 度鳥瞰...
#
#               2          3
# 0    114.160717  22.276965
# ...

# %%
# 根據第三列（經度）對行進行排序
df_sorted = df.sort_values(by=2)

# %%
df_sorted
# Out:
#                0                                                  1  \
# 15            大澳  Photo by ck wong \n 景點介紹、相片、遊記︰ \n http://www....
# 8    機場維修區 / 跑道尾  飛機升降, 日落, 草地, 指揮燈 \n Photo by mr.lab \n 景點介紹、相...
# 200  大嶼山昂平 / 寶蓮寺  Photo by kinsonleekakin \n 景點介紹、相片、遊記︰ \n http...
# 180          大鴉洲  http://www.dcfever.com/travel/attraction.php?i...
# 178          狗牙嶺  Photo by gosh \n 景點介紹、相片、遊記︰ \n http://www.dcf...
# ..           ...                                                ...
# 161           浪茄  (Photo by A-Lex) \n 景點介紹、相片、遊記︰ \n http://www....
# 142          蚺蛇尖  (Photo by Potato So ) \n 景點介紹、相片、遊記︰ \n http:/...
# 61           破邊洲  (Photo by shanamichi) \n http://www.dcfever.co...
# 185        糧船灣東岸  http://www.dcfever.com/travel/attraction.php?i...
# 14           東坪洲  Photo by stanley0010 \n 奇特壯觀的沉積岩和頁岩、日出風景 \n 景點...
#
#               2          3
# 15   113.862949  22.253969
# 8    113.894620  22.295132
# 200  113.907559  22.255439
# 180  113.911400  22.166978
# ...

# %%
# 將排序後的結果寫回 CSV 檔案
df_sorted.to_csv('DCFeverRecommend_sorted.csv', index=False, header=False)
